# %% [markdown]
# First of all, let's download the file. Thankfully wheelsaroundme allows public access to his Google Sheet spreadsheet, so we don't need to create and API key yada-yada-yada. Then we clean the data up: (check wheelsaroundme.ipynb for more details)
#
# 1. Some users put the "CC mesin" (engine cc) column in liters instaed
# 2. Gearbox values are wild
# 3. One user put "A" in the "Tahun" (model year) column
# 4. "Konsumsi dalam kota (KM/L)" (city fuel consumption in km/L) and "Konsumsi luar kota (KM/L)" (highway fuel consumption in km/L) values are also wild

# %%
from pathlib import Path

import pandas as pd

if Path("wam.csv").exists():
    df = pd.read_csv("wam.csv")
else:
    url = "https://docs.google.com/spreadsheets/d/1ttSU56TcDoZBzcCAIp7VPEjHDIcIuyi8wtb5FO3V2bA/export?format=csv"
    df = pd.read_csv(url)
    df.to_csv('wam.csv')

# cc
df.loc[df['CC mesin'] < 100, 'CC mesin'] *= 1000
# gearbox
df["gearbox_normalized"] = "AT"
df.loc[df["GEARBOX"].isin(["4MT", "5MT", "MT"]), "gearbox_normalized"] = "MT"
df.loc[df["GEARBOX"].isin(["CVT"]), "gearbox_normalized"] = "CVT"
# Tahun (model year)
df.loc[df["Tahun"].isin(["A"]), "Tahun"] = 1992
df["Tahun"] = df["Tahun"].astype("int")
# Fuel cons
df["city"] = pd.to_numeric(df["Konsumsi dalam kota (KM/L)"], errors='coerce')
df["hwy"] = pd.to_numeric(df["Konsumsi luar kota (KM/L)"], errors='coerce')
df = df.dropna(subset=["city"])
df = df.dropna(subset=["hwy"])
df = df.query("hwy < 100 & city < 100")
# brand
df['brand'] = df['Jenis Kendaraan'].str.split().str[0].str.lower()
df.loc[df["brand"].isin(["grandmax"]), "brand"] = "daihatsu"
df.loc[df["brand"].isin(["mercedes"]), "brand"] = "mercedes-benz"
df.loc[df["brand"].isin(["opel/chevrolet"]), "brand"] = "chevrolet"
df.loc[df["brand"].isin(["karimun"]), "brand"] = "suzuki"
df.loc[df["brand"].isin(["totota"]), "brand"] = "toyota"
df.loc[df["brand"].isin(["volkswagen"]), "brand"] = "vw"
# finally
df = df.loc[:, ['Tahun', "brand", "CC mesin", "gearbox_normalized", "city", "hwy"]]
df
# Out:
#       Tahun       brand  CC mesin gearbox_normalized  city   hwy
# 0      2011        audi    1800.0                CVT   8.0  12.0
# 4      2015         bmw    1500.0                 AT  12.0  16.0
# 5      2017         bmw    1500.0                 AT  12.5  19.0
# 6      1997         bmw    1800.0                 MT   7.0  11.5
# 7      1990         bmw    1800.0                 MT   6.0  10.0
# ...     ...         ...       ...                ...   ...   ...
# 1118   2012        mini    1600.0                 AT   9.0  14.0
# 1119   2001      toyota    3000.0                 AT   6.1   7.0
# 1121   1980  mitsubishi    1300.0                 AT   6.0   9.0
# 1129   1991         bmw    2500.0                 AT   5.0   7.0
# 1132   1988      toyota    1500.0                 AT  10.0  16.0
#
# [549 rows x 6 columns]

# %%
import numpy as np

all_brands_list = df["brand"].unique()
all_gearboxes_list = df["gearbox_normalized"].unique()
print(all_brands_list)
print(all_gearboxes_list)

df['brand_idx'] = df['brand'].apply(lambda x: int(np.where(all_brands_list == x)[0]))
df['gearbox_idx'] = df['gearbox_normalized'].apply(lambda x: int(np.where(all_gearboxes_list == x)[0]))

cc_max = df['CC mesin'].max()
cc_min = df['CC mesin'].min()
print(cc_min, cc_max)

year_max = df['Tahun'].max()
year_min = df['Tahun'].min()
print(year_min, year_max)

fuelcons_max = max(df["city"].max(), df["hwy"].max())
fuelcons_min = min(df["city"].min(), df["hwy"].min())
print(fuelcons_min, fuelcons_max)

df['cc_normalized'] = (df['CC mesin'] - cc_min) / (cc_max - cc_min)
df['year_normalized'] = (df['Tahun'] - year_min) / (year_max - year_min)
df['city_normalized'] = (df['city'] - fuelcons_min) / (fuelcons_max - fuelcons_min)
df['hwy_normalized'] = (df['hwy'] - fuelcons_min) / (fuelcons_max - fuelcons_min)
df
# Out:
# ['audi' 'bmw' 'cadillac' 'chevrolet' 'daihatsu' 'datsun' 'ford' 'honda'
#  'hyundai' 'jaguar' 'jeep' 'kia' 'land' 'lexus' 'mazda' 'mercedes-benz'
#  'mg' 'mini' 'mitsubishi' 'morris' 'nissan' 'peugeot' 'proton' 'range'
#  'renault' 'subaru' 'suzuki' 'timor' 'toyota' 'volvo' 'vw' 'wuling'
#  'daewoo']
# ['CVT' 'AT' 'MT']
# 849.0 7800.0
# 1961 2022
# 2.0 25.0
#       Tahun       brand  CC mesin gearbox_normalized  city   hwy  brand_idx  \
# 0      2011        audi    1800.0                CVT   8.0  12.0          0
# 4      2015         bmw    1500.0                 AT  12.0  16.0          1
# 5      2017         bmw    1500.0                 AT  12.5  19.0          1
# 6      1997         bmw    1800.0                 MT   7.0  11.5          1
# 7      1990         bmw    1800.0                 MT   6.0  10.0          1
# ...     ...         ...       ...                ...   ...   ...        ...
# 1118   2012        mini    1600.0                 AT   9.0  14.0         17
# 1119   2001      toyota    3000.0                 AT   6.1   7.0         28
# 1121   1980  mitsubishi    1300.0                 AT   6.0   9.0         18
# 1129   1991         bmw    2500.0                 AT   5.0   7.0          1
# 1132   1988      toyota    1500.0                 AT  10.0  16.0         28
#
#       gearbox_idx  cc_normalized  year_normalized  city_normalized  \
# 0               0       0.136815         0.819672         0.260870
# 4               1       0.093656         0.885246         0.434783
# 5               1       0.093656         0.918033         0.456522
# 6               2       0.136815         0.590164         0.217391
# 7               2       0.136815         0.475410         0.173913
# ...           ...            ...              ...              ...
# 1118            1       0.108042         0.836066         0.304348
# 1119            1       0.309452         0.655738         0.178261
# 1121            1       0.064883         0.311475         0.173913
# 1129            1       0.237520         0.491803         0.130435
# 1132            1       0.093656         0.442623         0.347826
#
#       hwy_normalized
# 0           0.434783
# 4           0.608696
# 5           0.739130
# 6           0.413043
# 7           0.347826
# ...              ...
# 1118        0.521739
# 1119        0.217391
# 1121        0.304348
# 1129        0.217391
# 1132        0.608696
#
# [549 rows x 12 columns]

# %%
import torch
from torch import nn

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

X_columns = ['brand_idx', 'gearbox_idx'] + ['year_normalized', 'cc_normalized']
X = torch.tensor(df[X_columns].values)
y_city = torch.tensor(df["city_normalized"].values)
y_city = y_city.reshape(-1, 1)
y_hwy = torch.tensor(df["hwy_normalized"].values)
y_hwy = y_hwy.reshape(-1, 1)
X
# Out:
# Using cuda device
# tensor([[ 0.0000,  0.0000,  0.8197,  0.1368],
#         [ 1.0000,  1.0000,  0.8852,  0.0937],
#         [ 1.0000,  1.0000,  0.9180,  0.0937],
#         ...,
#         [18.0000,  1.0000,  0.3115,  0.0649],
#         [ 1.0000,  1.0000,  0.4918,  0.2375],
#         [28.0000,  1.0000,  0.4426,  0.0937]], dtype=torch.float64)

# %% [markdown]
# Now let's try GAN. We first generate the Generator and Discriminator models
#
# For the embedding vector, we use a common embedding vectors for both the generator and discriminator, because we simply don't have sufficient data to train such embedding layers.
#
# (Also mainly because I couldn't figure out how to get the gradients to pass through an argmin/argmax. Pls send help lol)

# %%
latent_vector_dim = 1000
embedding_dim = 10
brand_embedding = nn.Embedding(len(all_brands_list), embedding_dim)
gearbox_embedding = nn.Embedding(len(all_gearboxes_list), embedding_dim)


class Generator(nn.Module):
    def __init__(self, brand_embedding, gearbox_embedding, model_output_dim=embedding_dim + 2):
        super(Generator, self).__init__()
        self.brand_embedding = brand_embedding
        self.gearbox_embedding = gearbox_embedding
        self.model = nn.Sequential(
            nn.Linear(latent_vector_dim + 2, model_output_dim // 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.BatchNorm1d(model_output_dim // 4),
            nn.Linear(model_output_dim // 4, model_output_dim // 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.BatchNorm1d(model_output_dim // 2),
            nn.Linear(model_output_dim // 2, model_output_dim),
            nn.Sigmoid(),
        )

    def reverse_embedding(self, output, emb_layer):  # https://discuss.pytorch.org/t/reverse-nn-embedding/142623/
        emb_weights = emb_layer.weight
        emb_size = output.size(0), output.size(1), -1, -1
        out_size = -1, -1, emb_weights.size(0), -1
        return torch.argmin(
            torch.abs(output.unsqueeze(2).expand(out_size) - emb_weights.unsqueeze(0).unsqueeze(0).expand(emb_size))
            .sum(dim=3), dim=2)

    def forward(self, x):
        return_model = self.model(x)
        brand_idx = self.reverse_embedding(return_model[:, 2:].unsqueeze(0), self.brand_embedding)
        gearbox_idx = self.reverse_embedding(return_model[:, 2:].unsqueeze(0), self.gearbox_embedding)
        return torch.cat([
            brand_idx.t(),
            gearbox_idx.t(),
            return_model[:, 0].unsqueeze(1),  # year
            return_model[:, 1].unsqueeze(1),  # cc
        ], dim=1)


class Discriminator(nn.Module):
    def __init__(self, brand_embedding, gearbox_embedding):
        super(Discriminator, self).__init__()
        self.brand_embedding = brand_embedding
        self.gearbox_embedding = gearbox_embedding
        self.input_tensor_dim = embedding_dim * 2 + 4  # 4 = year + cc + dalkot + lukot
        self.model = nn.Sequential(
            nn.Linear(self.input_tensor_dim, self.input_tensor_dim // 2),
            nn.ReLU(),
            nn.Linear(self.input_tensor_dim // 2, self.input_tensor_dim // 4),
            nn.ReLU(),
            nn.Linear(self.input_tensor_dim // 4, 1),
            nn.Sigmoid()
        )

    def combine_features(self, x):
        return torch.cat([
            x[:, 0].unsqueeze(1),  # dalkot
            x[:, 1].unsqueeze(1),  # lukot
            self.brand_embedding(x[:, 2].long()),
            self.gearbox_embedding(x[:, 3].long()),
            x[:, 4].unsqueeze(1),  # year
            x[:, 5].unsqueeze(1),  # cc
        ], dim=1)

    def forward(self, x):
        x = self.combine_features(x)
        return self.model(x)


generator = Generator(brand_embedding=brand_embedding, gearbox_embedding=gearbox_embedding)
discriminator = Discriminator(brand_embedding=brand_embedding, gearbox_embedding=gearbox_embedding)

print("THE GENERATOR:", generator)
print("THE DISCRIMINATOR:", discriminator)
# Out:
# THE GENERATOR: Generator(
#   (brand_embedding): Embedding(33, 10)
#   (gearbox_embedding): Embedding(3, 10)
#   (model): Sequential(
#     (0): Linear(in_features=1002, out_features=3, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=3, out_features=6, bias=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): BatchNorm1d(6, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Linear(in_features=6, out_features=12, bias=True)
#     (7): Sigmoid()
#   )
# )
# THE DISCRIMINATOR: Discriminator(
#   (brand_embedding): Embedding(33, 10)
#   (gearbox_embedding): Embedding(3, 10)
#   (model): Sequential(
#     (0): Linear(in_features=24, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=6, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=6, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %% [markdown]
# Let's generate a sample data, so we get some idea what the generator would come up with

# %%
city_labels = y_city.detach().clone().reshape(-1, 1).float()
city_labels = (city_labels - fuelcons_min) / (fuelcons_max - fuelcons_min)
hwy_labels = y_hwy.detach().clone().reshape(-1, 1).float()
hwy_labels = (hwy_labels - fuelcons_min) / (fuelcons_max - fuelcons_min)

true_labels = torch.cat((city_labels, hwy_labels), dim=1)
noise = torch.rand(size=(len(X), latent_vector_dim))

combined = torch.cat((true_labels, noise), dim=1)

generated_data = generator(combined)
print(generated_data)  # random, untrained
# Out:
# tensor([[21.0000,  0.0000,  0.8621,  0.4639],
#         [21.0000,  0.0000,  0.4473,  0.5300],
#         [21.0000,  0.0000,  0.5833,  0.5716],
#         ...,
#         [21.0000,  0.0000,  0.7893,  0.4524],
#         [21.0000,  0.0000,  0.5267,  0.5767],
#         [21.0000,  0.0000,  0.3292,  0.5320]], grad_fn=<CatBackward0>)

# %% [markdown]
# Let's train both the Generator and Discriminator together

# %%
lr = 0.001
batch_size = len(X)
true_data = X.detach().clone().float()
true_labels_data = torch.cat((true_labels, true_data), dim=1)

real_label = torch.full((batch_size, 1), 1.)  # Discriminator output 1 = real
fake_label = torch.full((batch_size, 1), 0.)  # Discriminator output 0 = fake


def train():
    generator_optimizer = torch.optim.Adam(generator.parameters(), lr=lr)
    discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=lr)
    loss = nn.BCELoss()

    for epoch in range(1000):
        generator.train()
        discriminator.train()
        generator_optimizer.zero_grad()
        discriminator_optimizer.zero_grad()

        noise = torch.rand(size=(batch_size, latent_vector_dim))
        generator_input = torch.cat((true_labels, noise), dim=1)
        generated_data = generator(generator_input)
        generated_data_with_labels = torch.cat((true_labels, generated_data), dim=1)

        generator_loss = loss(discriminator(generated_data_with_labels), real_label)
        generator_loss.backward()
        generator_optimizer.step()

        discriminated_real_data = discriminator(true_labels_data)
        discriminated_generated_data = discriminator(generated_data_with_labels.detach().clone())

        discriminated_real_data_loss = loss(discriminated_real_data, real_label)
        discriminated_generated_data_loss = loss(discriminated_generated_data, fake_label)
        total_loss = (discriminated_real_data_loss + discriminated_generated_data_loss)
        total_loss.backward()
        print(epoch, total_loss)
        discriminator_optimizer.step()
    return generator


generator = train()
# Out:
# brand generator weights tensor([ 0.0912, -1.0191,  0.0592,  0.5726,  1.6697,  0.1411, -0.0748, -0.7189,
#          0.2919,  0.7478], grad_fn=<SelectBackward0>)
# gearbox generator weights tensor([ 0.3213, -0.1936, -0.0199,  0.1620, -1.6089,  0.7501,  0.5640, -0.1063,
#         -0.0472, -0.3342], grad_fn=<SelectBackward0>)
# brand discriminator weights tensor([ 0.0912, -1.0191,  0.0592,  0.5726,  1.6697,  0.1411, -0.0748, -0.7189,
#          0.2919,  0.7478], grad_fn=<SelectBackward0>)
# gearbox discriminator weights tensor([ 0.3213, -0.1936, -0.0199,  0.1620, -1.6089,  0.7501,  0.5640, -0.1063,
#         -0.0472, -0.3342], grad_fn=<SelectBackward0>)
# 0 tensor(1.4016, grad_fn=<AddBackward0>)
# 1 tensor(1.4008, grad_fn=<AddBackward0>)
# 2 tensor(1.3999, grad_fn=<AddBackward0>)
# 3 tensor(1.3987, grad_fn=<AddBackward0>)
# 4 tensor(1.3980, grad_fn=<AddBackward0>)
# 5 tensor(1.3962, grad_fn=<AddBackward0>)
# 6 tensor(1.3951, grad_fn=<AddBackward0>)
# 7 tensor(1.3936, grad_fn=<AddBackward0>)
# 8 tensor(1.3924, grad_fn=<AddBackward0>)
# 9 tensor(1.3912, grad_fn=<AddBackward0>)
# 10 tensor(1.3901, grad_fn=<AddBackward0>)
# 11 tensor(1.3886, grad_fn=<AddBackward0>)
# 12 tensor(1.3868, grad_fn=<AddBackward0>)
# 13 tensor(1.3849, grad_fn=<AddBackward0>)
# 14 tensor(1.3839, grad_fn=<AddBackward0>)
# 15 tensor(1.3821, grad_fn=<AddBackward0>)
# 16 tensor(1.3804, grad_fn=<AddBackward0>)
# 17 tensor(1.3793, grad_fn=<AddBackward0>)
# 18 tensor(1.3775, grad_fn=<AddBackward0>)
# 19 tensor(1.3761, grad_fn=<AddBackward0>)
# 20 tensor(1.3738, grad_fn=<AddBackward0>)
# 21 tensor(1.3718, grad_fn=<AddBackward0>)
# 22 tensor(1.3693, grad_fn=<AddBackward0>)
# 23 tensor(1.3669, grad_fn=<AddBackward0>)
# 24 tensor(1.3656, grad_fn=<AddBackward0>)
# 25 tensor(1.3626, grad_fn=<AddBackward0>)
# 26 tensor(1.3604, grad_fn=<AddBackward0>)
# 27 tensor(1.3583, grad_fn=<AddBackward0>)
# 28 tensor(1.3564, grad_fn=<AddBackward0>)
# 29 tensor(1.3534, grad_fn=<AddBackward0>)
# 30 tensor(1.3497, grad_fn=<AddBackward0>)
# 31 tensor(1.3458, grad_fn=<AddBackward0>)
# 32 tensor(1.3418, grad_fn=<AddBackward0>)
# 33 tensor(1.3381, grad_fn=<AddBackward0>)
# 34 tensor(1.3344, grad_fn=<AddBackward0>)
# 35 tensor(1.3297, grad_fn=<AddBackward0>)
# 36 tensor(1.3257, grad_fn=<AddBackward0>)
# 37 tensor(1.3219, grad_fn=<AddBackward0>)
# 38 tensor(1.3179, grad_fn=<AddBackward0>)
# 39 tensor(1.3136, grad_fn=<AddBackward0>)
# 40 tensor(1.3087, grad_fn=<AddBackward0>)
# 41 tensor(1.3033, grad_fn=<AddBackward0>)
# 42 tensor(1.2974, grad_fn=<AddBackward0>)
# 43 tensor(1.2914, grad_fn=<AddBackward0>)
# 44 tensor(1.2856, grad_fn=<AddBackward0>)
# 45 tensor(1.2794, grad_fn=<AddBackward0>)
# 46 tensor(1.2723, grad_fn=<AddBackward0>)
# 47 tensor(1.2663, grad_fn=<AddBackward0>)
# 48 tensor(1.2597, grad_fn=<AddBackward0>)
# 49 tensor(1.2535, grad_fn=<AddBackward0>)
# 50 tensor(1.2465, grad_fn=<AddBackward0>)
# 51 tensor(1.2397, grad_fn=<AddBackward0>)
# 52 tensor(1.2324, grad_fn=<AddBackward0>)
# 53 tensor(1.2249, grad_fn=<AddBackward0>)
# 54 tensor(1.2175, grad_fn=<AddBackward0>)
# 55 tensor(1.2102, grad_fn=<AddBackward0>)
# 56 tensor(1.2026, grad_fn=<AddBackward0>)
# 57 tensor(1.1948, grad_fn=<AddBackward0>)
# 58 tensor(1.1874, grad_fn=<AddBackward0>)
# 59 tensor(1.1802, grad_fn=<AddBackward0>)
# 60 tensor(1.1719, grad_fn=<AddBackward0>)
# 61 tensor(1.1643, grad_fn=<AddBackward0>)
# 62 tensor(1.1556, grad_fn=<AddBackward0>)
# 63 tensor(1.1476, grad_fn=<AddBackward0>)
# 64 tensor(1.1391, grad_fn=<AddBackward0>)
# 65 tensor(1.1314, grad_fn=<AddBackward0>)
# 66 tensor(1.1228, grad_fn=<AddBackward0>)
# 67 tensor(1.1139, grad_fn=<AddBackward0>)
# 68 tensor(1.1055, grad_fn=<AddBackward0>)
# 69 tensor(1.0968, grad_fn=<AddBackward0>)
# 70 tensor(1.0881, grad_fn=<AddBackward0>)
# 71 tensor(1.0791, grad_fn=<AddBackward0>)
# 72 tensor(1.0700, grad_fn=<AddBackward0>)
# 73 tensor(1.0608, grad_fn=<AddBackward0>)
# 74 tensor(1.0531, grad_fn=<AddBackward0>)
# 75 tensor(1.0439, grad_fn=<AddBackward0>)
# 76 tensor(1.0353, grad_fn=<AddBackward0>)
# 77 tensor(1.0261, grad_fn=<AddBackward0>)
# 78 tensor(1.0174, grad_fn=<AddBackward0>)
# 79 tensor(1.0089, grad_fn=<AddBackward0>)
# 80 tensor(1.0001, grad_fn=<AddBackward0>)
# 81 tensor(0.9912, grad_fn=<AddBackward0>)
# 82 tensor(0.9831, grad_fn=<AddBackward0>)
# 83 tensor(0.9745, grad_fn=<AddBackward0>)
# 84 tensor(0.9659, grad_fn=<AddBackward0>)
# 85 tensor(0.9580, grad_fn=<AddBackward0>)
# 86 tensor(0.9495, grad_fn=<AddBackward0>)
# 87 tensor(0.9420, grad_fn=<AddBackward0>)
# 88 tensor(0.9339, grad_fn=<AddBackward0>)
# 89 tensor(0.9264, grad_fn=<AddBackward0>)
# 90 tensor(0.9191, grad_fn=<AddBackward0>)
# 91 tensor(0.9128, grad_fn=<AddBackward0>)
# 92 tensor(0.9066, grad_fn=<AddBackward0>)
# 93 tensor(0.9001, grad_fn=<AddBackward0>)
# 94 tensor(0.8952, grad_fn=<AddBackward0>)
# 95 tensor(0.8889, grad_fn=<AddBackward0>)
# 96 tensor(0.8837, grad_fn=<AddBackward0>)
# 97 tensor(0.8785, grad_fn=<AddBackward0>)
# 98 tensor(0.8742, grad_fn=<AddBackward0>)
# 99 tensor(0.8697, grad_fn=<AddBackward0>)
# 100 tensor(0.8648, grad_fn=<AddBackward0>)
# 101 tensor(0.8614, grad_fn=<AddBackward0>)
# 102 tensor(0.8570, grad_fn=<AddBackward0>)
# 103 tensor(0.8525, grad_fn=<AddBackward0>)
# 104 tensor(0.8486, grad_fn=<AddBackward0>)
# 105 tensor(0.8456, grad_fn=<AddBackward0>)
# 106 tensor(0.8415, grad_fn=<AddBackward0>)
# 107 tensor(0.8391, grad_fn=<AddBackward0>)
# 108 tensor(0.8356, grad_fn=<AddBackward0>)
# 109 tensor(0.8322, grad_fn=<AddBackward0>)
# 110 tensor(0.8289, grad_fn=<AddBackward0>)
# 111 tensor(0.8264, grad_fn=<AddBackward0>)
# 112 tensor(0.8233, grad_fn=<AddBackward0>)
# 113 tensor(0.8208, grad_fn=<AddBackward0>)
# 114 tensor(0.8183, grad_fn=<AddBackward0>)
# 115 tensor(0.8160, grad_fn=<AddBackward0>)
# 116 tensor(0.8127, grad_fn=<AddBackward0>)
# 117 tensor(0.8101, grad_fn=<AddBackward0>)
# 118 tensor(0.8086, grad_fn=<AddBackward0>)
# 119 tensor(0.8051, grad_fn=<AddBackward0>)
# 120 tensor(0.8034, grad_fn=<AddBackward0>)
# 121 tensor(0.8009, grad_fn=<AddBackward0>)
# 122 tensor(0.7987, grad_fn=<AddBackward0>)
# 123 tensor(0.7961, grad_fn=<AddBackward0>)
# 124 tensor(0.7945, grad_fn=<AddBackward0>)
# 125 tensor(0.7922, grad_fn=<AddBackward0>)
# 126 tensor(0.7900, grad_fn=<AddBackward0>)
# 127 tensor(0.7886, grad_fn=<AddBackward0>)
# 128 tensor(0.7866, grad_fn=<AddBackward0>)
# 129 tensor(0.7852, grad_fn=<AddBackward0>)
# 130 tensor(0.7830, grad_fn=<AddBackward0>)
# 131 tensor(0.7812, grad_fn=<AddBackward0>)
# 132 tensor(0.7801, grad_fn=<AddBackward0>)
# 133 tensor(0.7794, grad_fn=<AddBackward0>)
# 134 tensor(0.7773, grad_fn=<AddBackward0>)
# 135 tensor(0.7761, grad_fn=<AddBackward0>)
# 136 tensor(0.7754, grad_fn=<AddBackward0>)
# 137 tensor(0.7743, grad_fn=<AddBackward0>)
# 138 tensor(0.7728, grad_fn=<AddBackward0>)
# 139 tensor(0.7716, grad_fn=<AddBackward0>)
# 140 tensor(0.7718, grad_fn=<AddBackward0>)
# 141 tensor(0.7698, grad_fn=<AddBackward0>)
# 142 tensor(0.7678, grad_fn=<AddBackward0>)
# 143 tensor(0.7684, grad_fn=<AddBackward0>)
# 144 tensor(0.7672, grad_fn=<AddBackward0>)
# 145 tensor(0.7685, grad_fn=<AddBackward0>)
# 146 tensor(0.7670, grad_fn=<AddBackward0>)
# 147 tensor(0.7675, grad_fn=<AddBackward0>)
# 148 tensor(0.7700, grad_fn=<AddBackward0>)
# 149 tensor(0.7755, grad_fn=<AddBackward0>)
# 150 tensor(0.7607, grad_fn=<AddBackward0>)
# 151 tensor(0.7634, grad_fn=<AddBackward0>)
# 152 tensor(0.7749, grad_fn=<AddBackward0>)
# 153 tensor(0.7694, grad_fn=<AddBackward0>)
# 154 tensor(0.7678, grad_fn=<AddBackward0>)
# 155 tensor(0.7678, grad_fn=<AddBackward0>)
# 156 tensor(0.7718, grad_fn=<AddBackward0>)
# 157 tensor(0.7689, grad_fn=<AddBackward0>)
# 158 tensor(0.7702, grad_fn=<AddBackward0>)
# 159 tensor(0.7687, grad_fn=<AddBackward0>)
# 160 tensor(0.7704, grad_fn=<AddBackward0>)
# 161 tensor(0.7705, grad_fn=<AddBackward0>)
# 162 tensor(0.7683, grad_fn=<AddBackward0>)
# 163 tensor(0.7714, grad_fn=<AddBackward0>)
# 164 tensor(0.7703, grad_fn=<AddBackward0>)
# 165 tensor(0.7686, grad_fn=<AddBackward0>)
# 166 tensor(0.7668, grad_fn=<AddBackward0>)
# 167 tensor(0.7642, grad_fn=<AddBackward0>)
# 168 tensor(0.7633, grad_fn=<AddBackward0>)
# 169 tensor(0.7639, grad_fn=<AddBackward0>)
# 170 tensor(0.7620, grad_fn=<AddBackward0>)
# 171 tensor(0.7612, grad_fn=<AddBackward0>)
# 172 tensor(0.7595, grad_fn=<AddBackward0>)
# 173 tensor(0.7580, grad_fn=<AddBackward0>)
# 174 tensor(0.7580, grad_fn=<AddBackward0>)
# 175 tensor(0.7553, grad_fn=<AddBackward0>)
# 176 tensor(0.7533, grad_fn=<AddBackward0>)
# 177 tensor(0.7527, grad_fn=<AddBackward0>)
# 178 tensor(0.7511, grad_fn=<AddBackward0>)
# 179 tensor(0.7503, grad_fn=<AddBackward0>)
# 180 tensor(0.7489, grad_fn=<AddBackward0>)
# 181 tensor(0.7472, grad_fn=<AddBackward0>)
# 182 tensor(0.7474, grad_fn=<AddBackward0>)
# 183 tensor(0.7456, grad_fn=<AddBackward0>)
# 184 tensor(0.7445, grad_fn=<AddBackward0>)
# 185 tensor(0.7440, grad_fn=<AddBackward0>)
# 186 tensor(0.7424, grad_fn=<AddBackward0>)
# 187 tensor(0.7429, grad_fn=<AddBackward0>)
# 188 tensor(0.7415, grad_fn=<AddBackward0>)
# 189 tensor(0.7407, grad_fn=<AddBackward0>)
# 190 tensor(0.7399, grad_fn=<AddBackward0>)
# 191 tensor(0.7399, grad_fn=<AddBackward0>)
# 192 tensor(0.7390, grad_fn=<AddBackward0>)
# 193 tensor(0.7385, grad_fn=<AddBackward0>)
# 194 tensor(0.7378, grad_fn=<AddBackward0>)
# 195 tensor(0.7370, grad_fn=<AddBackward0>)
# 196 tensor(0.7365, grad_fn=<AddBackward0>)
# 197 tensor(0.7358, grad_fn=<AddBackward0>)
# 198 tensor(0.7349, grad_fn=<AddBackward0>)
# 199 tensor(0.7341, grad_fn=<AddBackward0>)
# 200 tensor(0.7334, grad_fn=<AddBackward0>)
# 201 tensor(0.7324, grad_fn=<AddBackward0>)
# 202 tensor(0.7314, grad_fn=<AddBackward0>)
# 203 tensor(0.7302, grad_fn=<AddBackward0>)
# 204 tensor(0.7294, grad_fn=<AddBackward0>)
# 205 tensor(0.7281, grad_fn=<AddBackward0>)
# 206 tensor(0.7274, grad_fn=<AddBackward0>)
# 207 tensor(0.7264, grad_fn=<AddBackward0>)
# 208 tensor(0.7255, grad_fn=<AddBackward0>)
# 209 tensor(0.7253, grad_fn=<AddBackward0>)
# 210 tensor(0.7243, grad_fn=<AddBackward0>)
# 211 tensor(0.7239, grad_fn=<AddBackward0>)
# 212 tensor(0.7233, grad_fn=<AddBackward0>)
# 213 tensor(0.7231, grad_fn=<AddBackward0>)
# 214 tensor(0.7226, grad_fn=<AddBackward0>)
# 215 tensor(0.7223, grad_fn=<AddBackward0>)
# 216 tensor(0.7222, grad_fn=<AddBackward0>)
# 217 tensor(0.7224, grad_fn=<AddBackward0>)
# 218 tensor(0.7222, grad_fn=<AddBackward0>)
# 219 tensor(0.7221, grad_fn=<AddBackward0>)
# 220 tensor(0.7219, grad_fn=<AddBackward0>)
# 221 tensor(0.7214, grad_fn=<AddBackward0>)
# 222 tensor(0.7211, grad_fn=<AddBackward0>)
# 223 tensor(0.7208, grad_fn=<AddBackward0>)
# 224 tensor(0.7208, grad_fn=<AddBackward0>)
# 225 tensor(0.7201, grad_fn=<AddBackward0>)
# 226 tensor(0.7199, grad_fn=<AddBackward0>)
# 227 tensor(0.7193, grad_fn=<AddBackward0>)
# 228 tensor(0.7189, grad_fn=<AddBackward0>)
# 229 tensor(0.7186, grad_fn=<AddBackward0>)
# 230 tensor(0.7190, grad_fn=<AddBackward0>)
# 231 tensor(0.7189, grad_fn=<AddBackward0>)
# 232 tensor(0.7185, grad_fn=<AddBackward0>)
# 233 tensor(0.7179, grad_fn=<AddBackward0>)
# 234 tensor(0.7182, grad_fn=<AddBackward0>)
# 235 tensor(0.7183, grad_fn=<AddBackward0>)
# 236 tensor(0.7177, grad_fn=<AddBackward0>)
# 237 tensor(0.7179, grad_fn=<AddBackward0>)
# 238 tensor(0.7172, grad_fn=<AddBackward0>)
# 239 tensor(0.7175, grad_fn=<AddBackward0>)
# 240 tensor(0.7176, grad_fn=<AddBackward0>)
# 241 tensor(0.7177, grad_fn=<AddBackward0>)
# 242 tensor(0.7171, grad_fn=<AddBackward0>)
# 243 tensor(0.7173, grad_fn=<AddBackward0>)
# 244 tensor(0.7171, grad_fn=<AddBackward0>)
# 245 tensor(0.7168, grad_fn=<AddBackward0>)
# 246 tensor(0.7165, grad_fn=<AddBackward0>)
# 247 tensor(0.7161, grad_fn=<AddBackward0>)
# 248 tensor(0.7159, grad_fn=<AddBackward0>)
# 249 tensor(0.7159, grad_fn=<AddBackward0>)
# 250 tensor(0.7158, grad_fn=<AddBackward0>)
# 251 tensor(0.7154, grad_fn=<AddBackward0>)
# 252 tensor(0.7156, grad_fn=<AddBackward0>)
# 253 tensor(0.7155, grad_fn=<AddBackward0>)
# 254 tensor(0.7152, grad_fn=<AddBackward0>)
# 255 tensor(0.7144, grad_fn=<AddBackward0>)
# 256 tensor(0.7149, grad_fn=<AddBackward0>)
# 257 tensor(0.7144, grad_fn=<AddBackward0>)
# 258 tensor(0.7145, grad_fn=<AddBackward0>)
# 259 tensor(0.7139, grad_fn=<AddBackward0>)
# 260 tensor(0.7128, grad_fn=<AddBackward0>)
# 261 tensor(0.7138, grad_fn=<AddBackward0>)
# 262 tensor(0.7127, grad_fn=<AddBackward0>)
# 263 tensor(0.7125, grad_fn=<AddBackward0>)
# 264 tensor(0.7122, grad_fn=<AddBackward0>)
# 265 tensor(0.7115, grad_fn=<AddBackward0>)
# 266 tensor(0.7120, grad_fn=<AddBackward0>)
# 267 tensor(0.7108, grad_fn=<AddBackward0>)
# 268 tensor(0.7112, grad_fn=<AddBackward0>)
# 269 tensor(0.7108, grad_fn=<AddBackward0>)
# 270 tensor(0.7102, grad_fn=<AddBackward0>)
# 271 tensor(0.7097, grad_fn=<AddBackward0>)
# 272 tensor(0.7092, grad_fn=<AddBackward0>)
# 273 tensor(0.7091, grad_fn=<AddBackward0>)
# 274 tensor(0.7079, grad_fn=<AddBackward0>)
# 275 tensor(0.7080, grad_fn=<AddBackward0>)
# 276 tensor(0.7081, grad_fn=<AddBackward0>)
# 277 tensor(0.7075, grad_fn=<AddBackward0>)
# 278 tensor(0.7078, grad_fn=<AddBackward0>)
# 279 tensor(0.7076, grad_fn=<AddBackward0>)
# 280 tensor(0.7073, grad_fn=<AddBackward0>)
# 281 tensor(0.7084, grad_fn=<AddBackward0>)
# 282 tensor(0.7079, grad_fn=<AddBackward0>)
# 283 tensor(0.7076, grad_fn=<AddBackward0>)
# 284 tensor(0.7073, grad_fn=<AddBackward0>)
# 285 tensor(0.7080, grad_fn=<AddBackward0>)
# 286 tensor(0.7081, grad_fn=<AddBackward0>)
# 287 tensor(0.7082, grad_fn=<AddBackward0>)
# 288 tensor(0.7085, grad_fn=<AddBackward0>)
# 289 tensor(0.7090, grad_fn=<AddBackward0>)
# 290 tensor(0.7088, grad_fn=<AddBackward0>)
# 291 tensor(0.7094, grad_fn=<AddBackward0>)
# 292 tensor(0.7098, grad_fn=<AddBackward0>)
# 293 tensor(0.7096, grad_fn=<AddBackward0>)
# 294 tensor(0.7093, grad_fn=<AddBackward0>)
# 295 tensor(0.7096, grad_fn=<AddBackward0>)
# 296 tensor(0.7098, grad_fn=<AddBackward0>)
# 297 tensor(0.7096, grad_fn=<AddBackward0>)
# 298 tensor(0.7098, grad_fn=<AddBackward0>)
# 299 tensor(0.7104, grad_fn=<AddBackward0>)
# 300 tensor(0.7097, grad_fn=<AddBackward0>)
# 301 tensor(0.7097, grad_fn=<AddBackward0>)
# 302 tensor(0.7104, grad_fn=<AddBackward0>)
# 303 tensor(0.7098, grad_fn=<AddBackward0>)
# 304 tensor(0.7106, grad_fn=<AddBackward0>)
# 305 tensor(0.7109, grad_fn=<AddBackward0>)
# 306 tensor(0.7109, grad_fn=<AddBackward0>)
# 307 tensor(0.7102, grad_fn=<AddBackward0>)
# 308 tensor(0.7102, grad_fn=<AddBackward0>)
# 309 tensor(0.7107, grad_fn=<AddBackward0>)
# 310 tensor(0.7109, grad_fn=<AddBackward0>)
# 311 tensor(0.7110, grad_fn=<AddBackward0>)
# 312 tensor(0.7105, grad_fn=<AddBackward0>)
# 313 tensor(0.7110, grad_fn=<AddBackward0>)
# 314 tensor(0.7109, grad_fn=<AddBackward0>)
# 315 tensor(0.7111, grad_fn=<AddBackward0>)
# 316 tensor(0.7107, grad_fn=<AddBackward0>)
# 317 tensor(0.7107, grad_fn=<AddBackward0>)
# 318 tensor(0.7102, grad_fn=<AddBackward0>)
# 319 tensor(0.7101, grad_fn=<AddBackward0>)
# 320 tensor(0.7105, grad_fn=<AddBackward0>)
# 321 tensor(0.7095, grad_fn=<AddBackward0>)
# 322 tensor(0.7103, grad_fn=<AddBackward0>)
# 323 tensor(0.7100, grad_fn=<AddBackward0>)
# 324 tensor(0.7098, grad_fn=<AddBackward0>)
# 325 tensor(0.7100, grad_fn=<AddBackward0>)
# 326 tensor(0.7100, grad_fn=<AddBackward0>)
# 327 tensor(0.7102, grad_fn=<AddBackward0>)
# 328 tensor(0.7099, grad_fn=<AddBackward0>)
# 329 tensor(0.7098, grad_fn=<AddBackward0>)
# 330 tensor(0.7101, grad_fn=<AddBackward0>)
# 331 tensor(0.7096, grad_fn=<AddBackward0>)
# 332 tensor(0.7099, grad_fn=<AddBackward0>)
# 333 tensor(0.7101, grad_fn=<AddBackward0>)
# 334 tensor(0.7098, grad_fn=<AddBackward0>)
# 335 tensor(0.7098, grad_fn=<AddBackward0>)
# 336 tensor(0.7101, grad_fn=<AddBackward0>)
# 337 tensor(0.7099, grad_fn=<AddBackward0>)
# 338 tensor(0.7098, grad_fn=<AddBackward0>)
# 339 tensor(0.7100, grad_fn=<AddBackward0>)
# 340 tensor(0.7102, grad_fn=<AddBackward0>)
# 341 tensor(0.7093, grad_fn=<AddBackward0>)
# 342 tensor(0.7100, grad_fn=<AddBackward0>)
# 343 tensor(0.7100, grad_fn=<AddBackward0>)
# 344 tensor(0.7098, grad_fn=<AddBackward0>)
# 345 tensor(0.7097, grad_fn=<AddBackward0>)
# 346 tensor(0.7095, grad_fn=<AddBackward0>)
# 347 tensor(0.7093, grad_fn=<AddBackward0>)
# 348 tensor(0.7092, grad_fn=<AddBackward0>)
# 349 tensor(0.7095, grad_fn=<AddBackward0>)
# 350 tensor(0.7095, grad_fn=<AddBackward0>)
# 351 tensor(0.7090, grad_fn=<AddBackward0>)
# 352 tensor(0.7090, grad_fn=<AddBackward0>)
# 353 tensor(0.7093, grad_fn=<AddBackward0>)
# 354 tensor(0.7091, grad_fn=<AddBackward0>)
# 355 tensor(0.7095, grad_fn=<AddBackward0>)
# 356 tensor(0.7088, grad_fn=<AddBackward0>)
# 357 tensor(0.7087, grad_fn=<AddBackward0>)
# 358 tensor(0.7084, grad_fn=<AddBackward0>)
# 359 tensor(0.7081, grad_fn=<AddBackward0>)
# 360 tensor(0.7083, grad_fn=<AddBackward0>)
# 361 tensor(0.7080, grad_fn=<AddBackward0>)
# 362 tensor(0.7081, grad_fn=<AddBackward0>)
# 363 tensor(0.7080, grad_fn=<AddBackward0>)
# 364 tensor(0.7081, grad_fn=<AddBackward0>)
# 365 tensor(0.7079, grad_fn=<AddBackward0>)
# 366 tensor(0.7080, grad_fn=<AddBackward0>)
# 367 tensor(0.7078, grad_fn=<AddBackward0>)
# 368 tensor(0.7074, grad_fn=<AddBackward0>)
# 369 tensor(0.7076, grad_fn=<AddBackward0>)
# 370 tensor(0.7071, grad_fn=<AddBackward0>)
# 371 tensor(0.7071, grad_fn=<AddBackward0>)
# 372 tensor(0.7072, grad_fn=<AddBackward0>)
# 373 tensor(0.7070, grad_fn=<AddBackward0>)
# 374 tensor(0.7070, grad_fn=<AddBackward0>)
# 375 tensor(0.7067, grad_fn=<AddBackward0>)
# 376 tensor(0.7065, grad_fn=<AddBackward0>)
# 377 tensor(0.7066, grad_fn=<AddBackward0>)
# 378 tensor(0.7067, grad_fn=<AddBackward0>)
# 379 tensor(0.7067, grad_fn=<AddBackward0>)
# 380 tensor(0.7064, grad_fn=<AddBackward0>)
# 381 tensor(0.7063, grad_fn=<AddBackward0>)
# 382 tensor(0.7065, grad_fn=<AddBackward0>)
# 383 tensor(0.7065, grad_fn=<AddBackward0>)
# 384 tensor(0.7065, grad_fn=<AddBackward0>)
# 385 tensor(0.7061, grad_fn=<AddBackward0>)
# 386 tensor(0.7062, grad_fn=<AddBackward0>)
# 387 tensor(0.7063, grad_fn=<AddBackward0>)
# 388 tensor(0.7064, grad_fn=<AddBackward0>)
# 389 tensor(0.7064, grad_fn=<AddBackward0>)
# 390 tensor(0.7062, grad_fn=<AddBackward0>)
# 391 tensor(0.7063, grad_fn=<AddBackward0>)
# 392 tensor(0.7064, grad_fn=<AddBackward0>)
# 393 tensor(0.7063, grad_fn=<AddBackward0>)
# 394 tensor(0.7061, grad_fn=<AddBackward0>)
# 395 tensor(0.7059, grad_fn=<AddBackward0>)
# 396 tensor(0.7058, grad_fn=<AddBackward0>)
# 397 tensor(0.7058, grad_fn=<AddBackward0>)
# 398 tensor(0.7059, grad_fn=<AddBackward0>)
# 399 tensor(0.7057, grad_fn=<AddBackward0>)
# 400 tensor(0.7056, grad_fn=<AddBackward0>)
# 401 tensor(0.7056, grad_fn=<AddBackward0>)
# 402 tensor(0.7055, grad_fn=<AddBackward0>)
# 403 tensor(0.7055, grad_fn=<AddBackward0>)
# 404 tensor(0.7053, grad_fn=<AddBackward0>)
# 405 tensor(0.7053, grad_fn=<AddBackward0>)
# 406 tensor(0.7052, grad_fn=<AddBackward0>)
# 407 tensor(0.7051, grad_fn=<AddBackward0>)
# 408 tensor(0.7051, grad_fn=<AddBackward0>)
# 409 tensor(0.7051, grad_fn=<AddBackward0>)
# 410 tensor(0.7051, grad_fn=<AddBackward0>)
# 411 tensor(0.7050, grad_fn=<AddBackward0>)
# 412 tensor(0.7049, grad_fn=<AddBackward0>)
# 413 tensor(0.7047, grad_fn=<AddBackward0>)
# 414 tensor(0.7045, grad_fn=<AddBackward0>)
# 415 tensor(0.7044, grad_fn=<AddBackward0>)
# 416 tensor(0.7043, grad_fn=<AddBackward0>)
# 417 tensor(0.7042, grad_fn=<AddBackward0>)
# 418 tensor(0.7042, grad_fn=<AddBackward0>)
# 419 tensor(0.7041, grad_fn=<AddBackward0>)
# 420 tensor(0.7041, grad_fn=<AddBackward0>)
# 421 tensor(0.7041, grad_fn=<AddBackward0>)
# 422 tensor(0.7041, grad_fn=<AddBackward0>)
# 423 tensor(0.7040, grad_fn=<AddBackward0>)
# 424 tensor(0.7039, grad_fn=<AddBackward0>)
# 425 tensor(0.7039, grad_fn=<AddBackward0>)
# 426 tensor(0.7039, grad_fn=<AddBackward0>)
# 427 tensor(0.7038, grad_fn=<AddBackward0>)
# 428 tensor(0.7038, grad_fn=<AddBackward0>)
# 429 tensor(0.7037, grad_fn=<AddBackward0>)
# 430 tensor(0.7037, grad_fn=<AddBackward0>)
# 431 tensor(0.7036, grad_fn=<AddBackward0>)
# 432 tensor(0.7036, grad_fn=<AddBackward0>)
# 433 tensor(0.7036, grad_fn=<AddBackward0>)
# 434 tensor(0.7035, grad_fn=<AddBackward0>)
# 435 tensor(0.7035, grad_fn=<AddBackward0>)
# 436 tensor(0.7035, grad_fn=<AddBackward0>)
# 437 tensor(0.7035, grad_fn=<AddBackward0>)
# 438 tensor(0.7035, grad_fn=<AddBackward0>)
# 439 tensor(0.7034, grad_fn=<AddBackward0>)
# 440 tensor(0.7033, grad_fn=<AddBackward0>)
# 441 tensor(0.7032, grad_fn=<AddBackward0>)
# 442 tensor(0.7031, grad_fn=<AddBackward0>)
# 443 tensor(0.7031, grad_fn=<AddBackward0>)
# 444 tensor(0.7031, grad_fn=<AddBackward0>)
# 445 tensor(0.7031, grad_fn=<AddBackward0>)
# 446 tensor(0.7031, grad_fn=<AddBackward0>)
# 447 tensor(0.7031, grad_fn=<AddBackward0>)
# 448 tensor(0.7031, grad_fn=<AddBackward0>)
# 449 tensor(0.7030, grad_fn=<AddBackward0>)
# 450 tensor(0.7030, grad_fn=<AddBackward0>)
# 451 tensor(0.7029, grad_fn=<AddBackward0>)
# 452 tensor(0.7028, grad_fn=<AddBackward0>)
# 453 tensor(0.7027, grad_fn=<AddBackward0>)
# 454 tensor(0.7027, grad_fn=<AddBackward0>)
# 455 tensor(0.7027, grad_fn=<AddBackward0>)
# 456 tensor(0.7027, grad_fn=<AddBackward0>)
# 457 tensor(0.7027, grad_fn=<AddBackward0>)
# 458 tensor(0.7027, grad_fn=<AddBackward0>)
# 459 tensor(0.7027, grad_fn=<AddBackward0>)
# 460 tensor(0.7027, grad_fn=<AddBackward0>)
# 461 tensor(0.7027, grad_fn=<AddBackward0>)
# 462 tensor(0.7026, grad_fn=<AddBackward0>)
# 463 tensor(0.7026, grad_fn=<AddBackward0>)
# 464 tensor(0.7026, grad_fn=<AddBackward0>)
# 465 tensor(0.7026, grad_fn=<AddBackward0>)
# 466 tensor(0.7026, grad_fn=<AddBackward0>)
# 467 tensor(0.7026, grad_fn=<AddBackward0>)
# 468 tensor(0.7025, grad_fn=<AddBackward0>)
# 469 tensor(0.7025, grad_fn=<AddBackward0>)
# 470 tensor(0.7024, grad_fn=<AddBackward0>)
# 471 tensor(0.7023, grad_fn=<AddBackward0>)
# 472 tensor(0.7023, grad_fn=<AddBackward0>)
# 473 tensor(0.7023, grad_fn=<AddBackward0>)
# 474 tensor(0.7023, grad_fn=<AddBackward0>)
# 475 tensor(0.7023, grad_fn=<AddBackward0>)
# 476 tensor(0.7023, grad_fn=<AddBackward0>)
# 477 tensor(0.7022, grad_fn=<AddBackward0>)
# 478 tensor(0.7022, grad_fn=<AddBackward0>)
# 479 tensor(0.7022, grad_fn=<AddBackward0>)
# 480 tensor(0.7021, grad_fn=<AddBackward0>)
# 481 tensor(0.7021, grad_fn=<AddBackward0>)
# 482 tensor(0.7020, grad_fn=<AddBackward0>)
# 483 tensor(0.7020, grad_fn=<AddBackward0>)
# 484 tensor(0.7019, grad_fn=<AddBackward0>)
# 485 tensor(0.7019, grad_fn=<AddBackward0>)
# 486 tensor(0.7019, grad_fn=<AddBackward0>)
# 487 tensor(0.7019, grad_fn=<AddBackward0>)
# 488 tensor(0.7019, grad_fn=<AddBackward0>)
# 489 tensor(0.7019, grad_fn=<AddBackward0>)
# 490 tensor(0.7018, grad_fn=<AddBackward0>)
# 491 tensor(0.7019, grad_fn=<AddBackward0>)
# 492 tensor(0.7018, grad_fn=<AddBackward0>)
# 493 tensor(0.7018, grad_fn=<AddBackward0>)
# 494 tensor(0.7017, grad_fn=<AddBackward0>)
# 495 tensor(0.7017, grad_fn=<AddBackward0>)
# 496 tensor(0.7016, grad_fn=<AddBackward0>)
# 497 tensor(0.7016, grad_fn=<AddBackward0>)
# 498 tensor(0.7016, grad_fn=<AddBackward0>)
# 499 tensor(0.7016, grad_fn=<AddBackward0>)
# 500 tensor(0.7016, grad_fn=<AddBackward0>)
# 501 tensor(0.7015, grad_fn=<AddBackward0>)
# 502 tensor(0.7014, grad_fn=<AddBackward0>)
# 503 tensor(0.7014, grad_fn=<AddBackward0>)
# 504 tensor(0.7014, grad_fn=<AddBackward0>)
# 505 tensor(0.7014, grad_fn=<AddBackward0>)
# 506 tensor(0.7014, grad_fn=<AddBackward0>)
# 507 tensor(0.7014, grad_fn=<AddBackward0>)
# 508 tensor(0.7014, grad_fn=<AddBackward0>)
# 509 tensor(0.7013, grad_fn=<AddBackward0>)
# 510 tensor(0.7013, grad_fn=<AddBackward0>)
# 511 tensor(0.7012, grad_fn=<AddBackward0>)
# 512 tensor(0.7012, grad_fn=<AddBackward0>)
# 513 tensor(0.7012, grad_fn=<AddBackward0>)
# 514 tensor(0.7012, grad_fn=<AddBackward0>)
# 515 tensor(0.7012, grad_fn=<AddBackward0>)
# 516 tensor(0.7012, grad_fn=<AddBackward0>)
# 517 tensor(0.7012, grad_fn=<AddBackward0>)
# 518 tensor(0.7012, grad_fn=<AddBackward0>)
# 519 tensor(0.7012, grad_fn=<AddBackward0>)
# 520 tensor(0.7011, grad_fn=<AddBackward0>)
# 521 tensor(0.7010, grad_fn=<AddBackward0>)
# 522 tensor(0.7010, grad_fn=<AddBackward0>)
# 523 tensor(0.7010, grad_fn=<AddBackward0>)
# 524 tensor(0.7010, grad_fn=<AddBackward0>)
# 525 tensor(0.7009, grad_fn=<AddBackward0>)
# 526 tensor(0.7009, grad_fn=<AddBackward0>)
# 527 tensor(0.7008, grad_fn=<AddBackward0>)
# 528 tensor(0.7008, grad_fn=<AddBackward0>)
# 529 tensor(0.7008, grad_fn=<AddBackward0>)
# 530 tensor(0.7008, grad_fn=<AddBackward0>)
# 531 tensor(0.7007, grad_fn=<AddBackward0>)
# 532 tensor(0.7007, grad_fn=<AddBackward0>)
# 533 tensor(0.7007, grad_fn=<AddBackward0>)
# 534 tensor(0.7007, grad_fn=<AddBackward0>)
# 535 tensor(0.7007, grad_fn=<AddBackward0>)
# 536 tensor(0.7008, grad_fn=<AddBackward0>)
# 537 tensor(0.7007, grad_fn=<AddBackward0>)
# 538 tensor(0.7006, grad_fn=<AddBackward0>)
# 539 tensor(0.7005, grad_fn=<AddBackward0>)
# 540 tensor(0.7004, grad_fn=<AddBackward0>)
# 541 tensor(0.7004, grad_fn=<AddBackward0>)
# 542 tensor(0.7004, grad_fn=<AddBackward0>)
# 543 tensor(0.7004, grad_fn=<AddBackward0>)
# 544 tensor(0.7004, grad_fn=<AddBackward0>)
# 545 tensor(0.7004, grad_fn=<AddBackward0>)
# 546 tensor(0.7004, grad_fn=<AddBackward0>)
# 547 tensor(0.7005, grad_fn=<AddBackward0>)
# 548 tensor(0.7004, grad_fn=<AddBackward0>)
# 549 tensor(0.7003, grad_fn=<AddBackward0>)
# 550 tensor(0.7003, grad_fn=<AddBackward0>)
# 551 tensor(0.7003, grad_fn=<AddBackward0>)
# 552 tensor(0.7003, grad_fn=<AddBackward0>)
# 553 tensor(0.7003, grad_fn=<AddBackward0>)
# 554 tensor(0.7002, grad_fn=<AddBackward0>)
# 555 tensor(0.7003, grad_fn=<AddBackward0>)
# 556 tensor(0.7003, grad_fn=<AddBackward0>)
# 557 tensor(0.7003, grad_fn=<AddBackward0>)
# 558 tensor(0.7002, grad_fn=<AddBackward0>)
# 559 tensor(0.7001, grad_fn=<AddBackward0>)
# 560 tensor(0.7000, grad_fn=<AddBackward0>)
# 561 tensor(0.6999, grad_fn=<AddBackward0>)
# 562 tensor(0.6999, grad_fn=<AddBackward0>)
# 563 tensor(0.6998, grad_fn=<AddBackward0>)
# 564 tensor(0.6999, grad_fn=<AddBackward0>)
# 565 tensor(0.6999, grad_fn=<AddBackward0>)
# 566 tensor(0.6999, grad_fn=<AddBackward0>)
# 567 tensor(0.7000, grad_fn=<AddBackward0>)
# 568 tensor(0.7001, grad_fn=<AddBackward0>)
# 569 tensor(0.7001, grad_fn=<AddBackward0>)
# 570 tensor(0.7001, grad_fn=<AddBackward0>)
# 571 tensor(0.7001, grad_fn=<AddBackward0>)
# 572 tensor(0.7000, grad_fn=<AddBackward0>)
# 573 tensor(0.7000, grad_fn=<AddBackward0>)
# 574 tensor(0.7000, grad_fn=<AddBackward0>)
# 575 tensor(0.7000, grad_fn=<AddBackward0>)
# 576 tensor(0.6999, grad_fn=<AddBackward0>)
# 577 tensor(0.6999, grad_fn=<AddBackward0>)
# 578 tensor(0.6999, grad_fn=<AddBackward0>)
# 579 tensor(0.6999, grad_fn=<AddBackward0>)
# 580 tensor(0.6999, grad_fn=<AddBackward0>)
# 581 tensor(0.6998, grad_fn=<AddBackward0>)
# 582 tensor(0.6998, grad_fn=<AddBackward0>)
# 583 tensor(0.6998, grad_fn=<AddBackward0>)
# 584 tensor(0.6998, grad_fn=<AddBackward0>)
# 585 tensor(0.6998, grad_fn=<AddBackward0>)
# 586 tensor(0.6998, grad_fn=<AddBackward0>)
# 587 tensor(0.6997, grad_fn=<AddBackward0>)
# 588 tensor(0.6997, grad_fn=<AddBackward0>)
# 589 tensor(0.6997, grad_fn=<AddBackward0>)
# 590 tensor(0.6998, grad_fn=<AddBackward0>)
# 591 tensor(0.6998, grad_fn=<AddBackward0>)
# 592 tensor(0.6997, grad_fn=<AddBackward0>)
# 593 tensor(0.6995, grad_fn=<AddBackward0>)
# 594 tensor(0.6995, grad_fn=<AddBackward0>)
# 595 tensor(0.6994, grad_fn=<AddBackward0>)
# 596 tensor(0.6995, grad_fn=<AddBackward0>)
# 597 tensor(0.6995, grad_fn=<AddBackward0>)
# 598 tensor(0.6995, grad_fn=<AddBackward0>)
# 599 tensor(0.6995, grad_fn=<AddBackward0>)
# 600 tensor(0.6995, grad_fn=<AddBackward0>)
# 601 tensor(0.6994, grad_fn=<AddBackward0>)
# 602 tensor(0.6994, grad_fn=<AddBackward0>)
# 603 tensor(0.6994, grad_fn=<AddBackward0>)
# 604 tensor(0.6993, grad_fn=<AddBackward0>)
# 605 tensor(0.6993, grad_fn=<AddBackward0>)
# 606 tensor(0.6993, grad_fn=<AddBackward0>)
# 607 tensor(0.6994, grad_fn=<AddBackward0>)
# 608 tensor(0.6994, grad_fn=<AddBackward0>)
# 609 tensor(0.6994, grad_fn=<AddBackward0>)
# 610 tensor(0.6995, grad_fn=<AddBackward0>)
# 611 tensor(0.6995, grad_fn=<AddBackward0>)
# 612 tensor(0.6996, grad_fn=<AddBackward0>)
# 613 tensor(0.6995, grad_fn=<AddBackward0>)
# 614 tensor(0.6994, grad_fn=<AddBackward0>)
# 615 tensor(0.6993, grad_fn=<AddBackward0>)
# 616 tensor(0.6993, grad_fn=<AddBackward0>)
# 617 tensor(0.6993, grad_fn=<AddBackward0>)
# 618 tensor(0.6992, grad_fn=<AddBackward0>)
# 619 tensor(0.6992, grad_fn=<AddBackward0>)
# 620 tensor(0.6993, grad_fn=<AddBackward0>)
# 621 tensor(0.6993, grad_fn=<AddBackward0>)
# 622 tensor(0.6993, grad_fn=<AddBackward0>)
# 623 tensor(0.6994, grad_fn=<AddBackward0>)
# 624 tensor(0.6993, grad_fn=<AddBackward0>)
# 625 tensor(0.6992, grad_fn=<AddBackward0>)
# 626 tensor(0.6992, grad_fn=<AddBackward0>)
# 627 tensor(0.6992, grad_fn=<AddBackward0>)
# 628 tensor(0.6993, grad_fn=<AddBackward0>)
# 629 tensor(0.6993, grad_fn=<AddBackward0>)
# 630 tensor(0.6992, grad_fn=<AddBackward0>)
# 631 tensor(0.6992, grad_fn=<AddBackward0>)
# 632 tensor(0.6992, grad_fn=<AddBackward0>)
# 633 tensor(0.6992, grad_fn=<AddBackward0>)
# 634 tensor(0.6992, grad_fn=<AddBackward0>)
# 635 tensor(0.6992, grad_fn=<AddBackward0>)
# 636 tensor(0.6992, grad_fn=<AddBackward0>)
# 637 tensor(0.6991, grad_fn=<AddBackward0>)
# 638 tensor(0.6991, grad_fn=<AddBackward0>)
# 639 tensor(0.6991, grad_fn=<AddBackward0>)
# 640 tensor(0.6991, grad_fn=<AddBackward0>)
# 641 tensor(0.6991, grad_fn=<AddBackward0>)
# 642 tensor(0.6992, grad_fn=<AddBackward0>)
# 643 tensor(0.6991, grad_fn=<AddBackward0>)
# 644 tensor(0.6989, grad_fn=<AddBackward0>)
# 645 tensor(0.6989, grad_fn=<AddBackward0>)
# 646 tensor(0.6989, grad_fn=<AddBackward0>)
# 647 tensor(0.6990, grad_fn=<AddBackward0>)
# 648 tensor(0.6990, grad_fn=<AddBackward0>)
# 649 tensor(0.6990, grad_fn=<AddBackward0>)
# 650 tensor(0.6990, grad_fn=<AddBackward0>)
# 651 tensor(0.6990, grad_fn=<AddBackward0>)
# 652 tensor(0.6990, grad_fn=<AddBackward0>)
# 653 tensor(0.6990, grad_fn=<AddBackward0>)
# 654 tensor(0.6990, grad_fn=<AddBackward0>)
# 655 tensor(0.6990, grad_fn=<AddBackward0>)
# 656 tensor(0.6990, grad_fn=<AddBackward0>)
# 657 tensor(0.6990, grad_fn=<AddBackward0>)
# 658 tensor(0.6989, grad_fn=<AddBackward0>)
# 659 tensor(0.6989, grad_fn=<AddBackward0>)
# 660 tensor(0.6989, grad_fn=<AddBackward0>)
# 661 tensor(0.6989, grad_fn=<AddBackward0>)
# 662 tensor(0.6989, grad_fn=<AddBackward0>)
# 663 tensor(0.6988, grad_fn=<AddBackward0>)
# 664 tensor(0.6988, grad_fn=<AddBackward0>)
# 665 tensor(0.6987, grad_fn=<AddBackward0>)
# 666 tensor(0.6987, grad_fn=<AddBackward0>)
# 667 tensor(0.6988, grad_fn=<AddBackward0>)
# 668 tensor(0.6988, grad_fn=<AddBackward0>)
# 669 tensor(0.6989, grad_fn=<AddBackward0>)
# 670 tensor(0.6988, grad_fn=<AddBackward0>)
# 671 tensor(0.6987, grad_fn=<AddBackward0>)
# 672 tensor(0.6987, grad_fn=<AddBackward0>)
# 673 tensor(0.6987, grad_fn=<AddBackward0>)
# 674 tensor(0.6987, grad_fn=<AddBackward0>)
# 675 tensor(0.6987, grad_fn=<AddBackward0>)
# 676 tensor(0.6988, grad_fn=<AddBackward0>)
# 677 tensor(0.6988, grad_fn=<AddBackward0>)
# 678 tensor(0.6987, grad_fn=<AddBackward0>)
# 679 tensor(0.6986, grad_fn=<AddBackward0>)
# 680 tensor(0.6986, grad_fn=<AddBackward0>)
# 681 tensor(0.6986, grad_fn=<AddBackward0>)
# 682 tensor(0.6986, grad_fn=<AddBackward0>)
# 683 tensor(0.6987, grad_fn=<AddBackward0>)
# 684 tensor(0.6987, grad_fn=<AddBackward0>)
# 685 tensor(0.6987, grad_fn=<AddBackward0>)
# 686 tensor(0.6986, grad_fn=<AddBackward0>)
# 687 tensor(0.6986, grad_fn=<AddBackward0>)
# 688 tensor(0.6985, grad_fn=<AddBackward0>)
# 689 tensor(0.6986, grad_fn=<AddBackward0>)
# 690 tensor(0.6985, grad_fn=<AddBackward0>)
# 691 tensor(0.6986, grad_fn=<AddBackward0>)
# 692 tensor(0.6986, grad_fn=<AddBackward0>)
# 693 tensor(0.6986, grad_fn=<AddBackward0>)
# 694 tensor(0.6985, grad_fn=<AddBackward0>)
# 695 tensor(0.6984, grad_fn=<AddBackward0>)
# 696 tensor(0.6983, grad_fn=<AddBackward0>)
# 697 tensor(0.6983, grad_fn=<AddBackward0>)
# 698 tensor(0.6983, grad_fn=<AddBackward0>)
# 699 tensor(0.6984, grad_fn=<AddBackward0>)
# 700 tensor(0.6985, grad_fn=<AddBackward0>)
# 701 tensor(0.6985, grad_fn=<AddBackward0>)
# 702 tensor(0.6985, grad_fn=<AddBackward0>)
# 703 tensor(0.6984, grad_fn=<AddBackward0>)
# 704 tensor(0.6984, grad_fn=<AddBackward0>)
# 705 tensor(0.6983, grad_fn=<AddBackward0>)
# 706 tensor(0.6983, grad_fn=<AddBackward0>)
# 707 tensor(0.6983, grad_fn=<AddBackward0>)
# 708 tensor(0.6984, grad_fn=<AddBackward0>)
# 709 tensor(0.6984, grad_fn=<AddBackward0>)
# 710 tensor(0.6984, grad_fn=<AddBackward0>)
# 711 tensor(0.6984, grad_fn=<AddBackward0>)
# 712 tensor(0.6983, grad_fn=<AddBackward0>)
# 713 tensor(0.6983, grad_fn=<AddBackward0>)
# 714 tensor(0.6984, grad_fn=<AddBackward0>)
# 715 tensor(0.6984, grad_fn=<AddBackward0>)
# 716 tensor(0.6984, grad_fn=<AddBackward0>)
# 717 tensor(0.6984, grad_fn=<AddBackward0>)
# 718 tensor(0.6984, grad_fn=<AddBackward0>)
# 719 tensor(0.6985, grad_fn=<AddBackward0>)
# 720 tensor(0.6984, grad_fn=<AddBackward0>)
# 721 tensor(0.6983, grad_fn=<AddBackward0>)
# 722 tensor(0.6982, grad_fn=<AddBackward0>)
# 723 tensor(0.6982, grad_fn=<AddBackward0>)
# 724 tensor(0.6982, grad_fn=<AddBackward0>)
# 725 tensor(0.6980, grad_fn=<AddBackward0>)
# 726 tensor(0.6979, grad_fn=<AddBackward0>)
# 727 tensor(0.6978, grad_fn=<AddBackward0>)
# 728 tensor(0.6977, grad_fn=<AddBackward0>)
# 729 tensor(0.6977, grad_fn=<AddBackward0>)
# 730 tensor(0.6978, grad_fn=<AddBackward0>)
# 731 tensor(0.6979, grad_fn=<AddBackward0>)
# 732 tensor(0.6980, grad_fn=<AddBackward0>)
# 733 tensor(0.6981, grad_fn=<AddBackward0>)
# 734 tensor(0.6980, grad_fn=<AddBackward0>)
# 735 tensor(0.6979, grad_fn=<AddBackward0>)
# 736 tensor(0.6978, grad_fn=<AddBackward0>)
# 737 tensor(0.6978, grad_fn=<AddBackward0>)
# 738 tensor(0.6979, grad_fn=<AddBackward0>)
# 739 tensor(0.6980, grad_fn=<AddBackward0>)
# 740 tensor(0.6977, grad_fn=<AddBackward0>)
# 741 tensor(0.6976, grad_fn=<AddBackward0>)
# 742 tensor(0.6975, grad_fn=<AddBackward0>)
# 743 tensor(0.6976, grad_fn=<AddBackward0>)
# 744 tensor(0.6977, grad_fn=<AddBackward0>)
# 745 tensor(0.6978, grad_fn=<AddBackward0>)
# 746 tensor(0.6978, grad_fn=<AddBackward0>)
# 747 tensor(0.6980, grad_fn=<AddBackward0>)
# 748 tensor(0.6981, grad_fn=<AddBackward0>)
# 749 tensor(0.6983, grad_fn=<AddBackward0>)
# 750 tensor(0.6984, grad_fn=<AddBackward0>)
# 751 tensor(0.6981, grad_fn=<AddBackward0>)
# 752 tensor(0.6980, grad_fn=<AddBackward0>)
# 753 tensor(0.6979, grad_fn=<AddBackward0>)
# 754 tensor(0.6979, grad_fn=<AddBackward0>)
# 755 tensor(0.6979, grad_fn=<AddBackward0>)
# 756 tensor(0.6980, grad_fn=<AddBackward0>)
# 757 tensor(0.6978, grad_fn=<AddBackward0>)
# 758 tensor(0.6978, grad_fn=<AddBackward0>)
# 759 tensor(0.6979, grad_fn=<AddBackward0>)
# 760 tensor(0.6980, grad_fn=<AddBackward0>)
# 761 tensor(0.6982, grad_fn=<AddBackward0>)
# 762 tensor(0.6984, grad_fn=<AddBackward0>)
# 763 tensor(0.6986, grad_fn=<AddBackward0>)
# 764 tensor(0.6987, grad_fn=<AddBackward0>)
# 765 tensor(0.6987, grad_fn=<AddBackward0>)
# 766 tensor(0.6982, grad_fn=<AddBackward0>)
# 767 tensor(0.6978, grad_fn=<AddBackward0>)
# 768 tensor(0.6975, grad_fn=<AddBackward0>)
# 769 tensor(0.6974, grad_fn=<AddBackward0>)
# 770 tensor(0.6973, grad_fn=<AddBackward0>)
# 771 tensor(0.6974, grad_fn=<AddBackward0>)
# 772 tensor(0.6974, grad_fn=<AddBackward0>)
# 773 tensor(0.6968, grad_fn=<AddBackward0>)
# 774 tensor(0.6964, grad_fn=<AddBackward0>)
# 775 tensor(0.6961, grad_fn=<AddBackward0>)
# 776 tensor(0.6960, grad_fn=<AddBackward0>)
# 777 tensor(0.6959, grad_fn=<AddBackward0>)
# 778 tensor(0.6959, grad_fn=<AddBackward0>)
# 779 tensor(0.6960, grad_fn=<AddBackward0>)
# 780 tensor(0.6962, grad_fn=<AddBackward0>)
# 781 tensor(0.6965, grad_fn=<AddBackward0>)
# 782 tensor(0.6968, grad_fn=<AddBackward0>)
# 783 tensor(0.6971, grad_fn=<AddBackward0>)
# 784 tensor(0.6973, grad_fn=<AddBackward0>)
# 785 tensor(0.6976, grad_fn=<AddBackward0>)
# 786 tensor(0.6978, grad_fn=<AddBackward0>)
# 787 tensor(0.6982, grad_fn=<AddBackward0>)
# 788 tensor(0.6985, grad_fn=<AddBackward0>)
# 789 tensor(0.6989, grad_fn=<AddBackward0>)
# 790 tensor(0.6993, grad_fn=<AddBackward0>)
# 791 tensor(0.6991, grad_fn=<AddBackward0>)
# 792 tensor(0.6990, grad_fn=<AddBackward0>)
# 793 tensor(0.6989, grad_fn=<AddBackward0>)
# 794 tensor(0.6988, grad_fn=<AddBackward0>)
# 795 tensor(0.6988, grad_fn=<AddBackward0>)
# 796 tensor(0.6989, grad_fn=<AddBackward0>)
# 797 tensor(0.6984, grad_fn=<AddBackward0>)
# 798 tensor(0.6980, grad_fn=<AddBackward0>)
# 799 tensor(0.6978, grad_fn=<AddBackward0>)
# 800 tensor(0.6977, grad_fn=<AddBackward0>)
# 801 tensor(0.6976, grad_fn=<AddBackward0>)
# 802 tensor(0.6977, grad_fn=<AddBackward0>)
# 803 tensor(0.6978, grad_fn=<AddBackward0>)
# 804 tensor(0.6980, grad_fn=<AddBackward0>)
# 805 tensor(0.6981, grad_fn=<AddBackward0>)
# 806 tensor(0.6979, grad_fn=<AddBackward0>)
# 807 tensor(0.6977, grad_fn=<AddBackward0>)
# 808 tensor(0.6976, grad_fn=<AddBackward0>)
# 809 tensor(0.6976, grad_fn=<AddBackward0>)
# 810 tensor(0.6978, grad_fn=<AddBackward0>)
# 811 tensor(0.6968, grad_fn=<AddBackward0>)
# 812 tensor(0.6962, grad_fn=<AddBackward0>)
# 813 tensor(0.6958, grad_fn=<AddBackward0>)
# 814 tensor(0.6956, grad_fn=<AddBackward0>)
# 815 tensor(0.6955, grad_fn=<AddBackward0>)
# 816 tensor(0.6956, grad_fn=<AddBackward0>)
# 817 tensor(0.6958, grad_fn=<AddBackward0>)
# 818 tensor(0.6961, grad_fn=<AddBackward0>)
# 819 tensor(0.6964, grad_fn=<AddBackward0>)
# 820 tensor(0.6970, grad_fn=<AddBackward0>)
# 821 tensor(0.6975, grad_fn=<AddBackward0>)
# 822 tensor(0.6978, grad_fn=<AddBackward0>)
# 823 tensor(0.6965, grad_fn=<AddBackward0>)
# 824 tensor(0.6953, grad_fn=<AddBackward0>)
# 825 tensor(0.6946, grad_fn=<AddBackward0>)
# 826 tensor(0.6940, grad_fn=<AddBackward0>)
# 827 tensor(0.6936, grad_fn=<AddBackward0>)
# 828 tensor(0.6935, grad_fn=<AddBackward0>)
# 829 tensor(0.6934, grad_fn=<AddBackward0>)
# 830 tensor(0.6934, grad_fn=<AddBackward0>)
# 831 tensor(0.6936, grad_fn=<AddBackward0>)
# 832 tensor(0.6939, grad_fn=<AddBackward0>)
# 833 tensor(0.6942, grad_fn=<AddBackward0>)
# 834 tensor(0.6947, grad_fn=<AddBackward0>)
# 835 tensor(0.6954, grad_fn=<AddBackward0>)
# 836 tensor(0.6959, grad_fn=<AddBackward0>)
# 837 tensor(0.6965, grad_fn=<AddBackward0>)
# 838 tensor(0.6972, grad_fn=<AddBackward0>)
# 839 tensor(0.6978, grad_fn=<AddBackward0>)
# 840 tensor(0.6983, grad_fn=<AddBackward0>)
# 841 tensor(0.6989, grad_fn=<AddBackward0>)
# 842 tensor(0.6994, grad_fn=<AddBackward0>)
# 843 tensor(0.6998, grad_fn=<AddBackward0>)
# 844 tensor(0.7003, grad_fn=<AddBackward0>)
# 845 tensor(0.7007, grad_fn=<AddBackward0>)
# 846 tensor(0.7010, grad_fn=<AddBackward0>)
# 847 tensor(0.7013, grad_fn=<AddBackward0>)
# 848 tensor(0.7015, grad_fn=<AddBackward0>)
# 849 tensor(0.7016, grad_fn=<AddBackward0>)
# 850 tensor(0.7018, grad_fn=<AddBackward0>)
# 851 tensor(0.7018, grad_fn=<AddBackward0>)
# 852 tensor(0.7018, grad_fn=<AddBackward0>)
# 853 tensor(0.7018, grad_fn=<AddBackward0>)
# 854 tensor(0.7016, grad_fn=<AddBackward0>)
# 855 tensor(0.7013, grad_fn=<AddBackward0>)
# 856 tensor(0.7011, grad_fn=<AddBackward0>)
# 857 tensor(0.7008, grad_fn=<AddBackward0>)
# 858 tensor(0.7005, grad_fn=<AddBackward0>)
# 859 tensor(0.7003, grad_fn=<AddBackward0>)
# 860 tensor(0.7001, grad_fn=<AddBackward0>)
# 861 tensor(0.6998, grad_fn=<AddBackward0>)
# 862 tensor(0.6994, grad_fn=<AddBackward0>)
# 863 tensor(0.6992, grad_fn=<AddBackward0>)
# 864 tensor(0.6989, grad_fn=<AddBackward0>)
# 865 tensor(0.6987, grad_fn=<AddBackward0>)
# 866 tensor(0.6985, grad_fn=<AddBackward0>)
# 867 tensor(0.6984, grad_fn=<AddBackward0>)
# 868 tensor(0.6984, grad_fn=<AddBackward0>)
# 869 tensor(0.6979, grad_fn=<AddBackward0>)
# 870 tensor(0.6977, grad_fn=<AddBackward0>)
# 871 tensor(0.6975, grad_fn=<AddBackward0>)
# 872 tensor(0.6974, grad_fn=<AddBackward0>)
# 873 tensor(0.6974, grad_fn=<AddBackward0>)
# 874 tensor(0.6975, grad_fn=<AddBackward0>)
# 875 tensor(0.6975, grad_fn=<AddBackward0>)
# 876 tensor(0.6976, grad_fn=<AddBackward0>)
# 877 tensor(0.6976, grad_fn=<AddBackward0>)
# 878 tensor(0.6975, grad_fn=<AddBackward0>)
# 879 tensor(0.6973, grad_fn=<AddBackward0>)
# 880 tensor(0.6971, grad_fn=<AddBackward0>)
# 881 tensor(0.6971, grad_fn=<AddBackward0>)
# 882 tensor(0.6971, grad_fn=<AddBackward0>)
# 883 tensor(0.6972, grad_fn=<AddBackward0>)
# 884 tensor(0.6966, grad_fn=<AddBackward0>)
# 885 tensor(0.6961, grad_fn=<AddBackward0>)
# 886 tensor(0.6958, grad_fn=<AddBackward0>)
# 887 tensor(0.6956, grad_fn=<AddBackward0>)
# 888 tensor(0.6956, grad_fn=<AddBackward0>)
# 889 tensor(0.6956, grad_fn=<AddBackward0>)
# 890 tensor(0.6958, grad_fn=<AddBackward0>)
# 891 tensor(0.6960, grad_fn=<AddBackward0>)
# 892 tensor(0.6962, grad_fn=<AddBackward0>)
# 893 tensor(0.6965, grad_fn=<AddBackward0>)
# 894 tensor(0.6969, grad_fn=<AddBackward0>)
# 895 tensor(0.6973, grad_fn=<AddBackward0>)
# 896 tensor(0.6975, grad_fn=<AddBackward0>)
# 897 tensor(0.6976, grad_fn=<AddBackward0>)
# 898 tensor(0.6977, grad_fn=<AddBackward0>)
# 899 tensor(0.6973, grad_fn=<AddBackward0>)
# 900 tensor(0.6971, grad_fn=<AddBackward0>)
# 901 tensor(0.6969, grad_fn=<AddBackward0>)
# 902 tensor(0.6968, grad_fn=<AddBackward0>)
# 903 tensor(0.6967, grad_fn=<AddBackward0>)
# 904 tensor(0.6968, grad_fn=<AddBackward0>)
# 905 tensor(0.6969, grad_fn=<AddBackward0>)
# 906 tensor(0.6970, grad_fn=<AddBackward0>)
# 907 tensor(0.6974, grad_fn=<AddBackward0>)
# 908 tensor(0.6967, grad_fn=<AddBackward0>)
# 909 tensor(0.6962, grad_fn=<AddBackward0>)
# 910 tensor(0.6958, grad_fn=<AddBackward0>)
# 911 tensor(0.6956, grad_fn=<AddBackward0>)
# 912 tensor(0.6956, grad_fn=<AddBackward0>)
# 913 tensor(0.6958, grad_fn=<AddBackward0>)
# 914 tensor(0.6959, grad_fn=<AddBackward0>)
# 915 tensor(0.6961, grad_fn=<AddBackward0>)
# 916 tensor(0.6963, grad_fn=<AddBackward0>)
# 917 tensor(0.6966, grad_fn=<AddBackward0>)
# 918 tensor(0.6968, grad_fn=<AddBackward0>)
# 919 tensor(0.6971, grad_fn=<AddBackward0>)
# 920 tensor(0.6973, grad_fn=<AddBackward0>)
# 921 tensor(0.6977, grad_fn=<AddBackward0>)
# 922 tensor(0.6978, grad_fn=<AddBackward0>)
# 923 tensor(0.6974, grad_fn=<AddBackward0>)
# 924 tensor(0.6970, grad_fn=<AddBackward0>)
# 925 tensor(0.6968, grad_fn=<AddBackward0>)
# 926 tensor(0.6966, grad_fn=<AddBackward0>)
# 927 tensor(0.6965, grad_fn=<AddBackward0>)
# 928 tensor(0.6966, grad_fn=<AddBackward0>)
# 929 tensor(0.6968, grad_fn=<AddBackward0>)
# 930 tensor(0.6968, grad_fn=<AddBackward0>)
# 931 tensor(0.6970, grad_fn=<AddBackward0>)
# 932 tensor(0.6972, grad_fn=<AddBackward0>)
# 933 tensor(0.6974, grad_fn=<AddBackward0>)
# 934 tensor(0.6976, grad_fn=<AddBackward0>)
# 935 tensor(0.6978, grad_fn=<AddBackward0>)
# 936 tensor(0.6979, grad_fn=<AddBackward0>)
# 937 tensor(0.6980, grad_fn=<AddBackward0>)
# 938 tensor(0.6981, grad_fn=<AddBackward0>)
# 939 tensor(0.6983, grad_fn=<AddBackward0>)
# 940 tensor(0.6983, grad_fn=<AddBackward0>)
# 941 tensor(0.6984, grad_fn=<AddBackward0>)
# 942 tensor(0.6986, grad_fn=<AddBackward0>)
# 943 tensor(0.6987, grad_fn=<AddBackward0>)
# 944 tensor(0.6988, grad_fn=<AddBackward0>)
# 945 tensor(0.6989, grad_fn=<AddBackward0>)
# 946 tensor(0.6988, grad_fn=<AddBackward0>)
# 947 tensor(0.6987, grad_fn=<AddBackward0>)
# 948 tensor(0.6985, grad_fn=<AddBackward0>)
# 949 tensor(0.6984, grad_fn=<AddBackward0>)
# 950 tensor(0.6983, grad_fn=<AddBackward0>)
# 951 tensor(0.6982, grad_fn=<AddBackward0>)
# 952 tensor(0.6981, grad_fn=<AddBackward0>)
# 953 tensor(0.6981, grad_fn=<AddBackward0>)
# 954 tensor(0.6982, grad_fn=<AddBackward0>)
# 955 tensor(0.6982, grad_fn=<AddBackward0>)
# 956 tensor(0.6980, grad_fn=<AddBackward0>)
# 957 tensor(0.6979, grad_fn=<AddBackward0>)
# 958 tensor(0.6979, grad_fn=<AddBackward0>)
# 959 tensor(0.6979, grad_fn=<AddBackward0>)
# 960 tensor(0.6959, grad_fn=<AddBackward0>)
# 961 tensor(0.6942, grad_fn=<AddBackward0>)
# 962 tensor(0.6928, grad_fn=<AddBackward0>)
# 963 tensor(0.6917, grad_fn=<AddBackward0>)
# 964 tensor(0.6911, grad_fn=<AddBackward0>)
# 965 tensor(0.6904, grad_fn=<AddBackward0>)
# 966 tensor(0.6901, grad_fn=<AddBackward0>)
# 967 tensor(0.6899, grad_fn=<AddBackward0>)
# 968 tensor(0.6900, grad_fn=<AddBackward0>)
# 969 tensor(0.6904, grad_fn=<AddBackward0>)
# 970 tensor(0.6908, grad_fn=<AddBackward0>)
# 971 tensor(0.6910, grad_fn=<AddBackward0>)
# 972 tensor(0.6914, grad_fn=<AddBackward0>)
# 973 tensor(0.6920, grad_fn=<AddBackward0>)
# 974 tensor(0.6926, grad_fn=<AddBackward0>)
# 975 tensor(0.6934, grad_fn=<AddBackward0>)
# 976 tensor(0.6944, grad_fn=<AddBackward0>)
# 977 tensor(0.6953, grad_fn=<AddBackward0>)
# 978 tensor(0.6963, grad_fn=<AddBackward0>)
# 979 tensor(0.6972, grad_fn=<AddBackward0>)
# 980 tensor(0.6980, grad_fn=<AddBackward0>)
# 981 tensor(0.6988, grad_fn=<AddBackward0>)
# 982 tensor(0.6994, grad_fn=<AddBackward0>)
# 983 tensor(0.7000, grad_fn=<AddBackward0>)
# 984 tensor(0.7005, grad_fn=<AddBackward0>)
# 985 tensor(0.7009, grad_fn=<AddBackward0>)
# 986 tensor(0.7013, grad_fn=<AddBackward0>)
# 987 tensor(0.7016, grad_fn=<AddBackward0>)
# 988 tensor(0.7018, grad_fn=<AddBackward0>)
# 989 tensor(0.7017, grad_fn=<AddBackward0>)
# 990 tensor(0.7015, grad_fn=<AddBackward0>)
# 991 tensor(0.7013, grad_fn=<AddBackward0>)
# 992 tensor(0.7011, grad_fn=<AddBackward0>)
# 993 tensor(0.7008, grad_fn=<AddBackward0>)
# 994 tensor(0.7006, grad_fn=<AddBackward0>)
# 995 tensor(0.7003, grad_fn=<AddBackward0>)
# 996 tensor(0.7000, grad_fn=<AddBackward0>)
# 997 tensor(0.6997, grad_fn=<AddBackward0>)
# 998 tensor(0.6994, grad_fn=<AddBackward0>)
# 999 tensor(0.6991, grad_fn=<AddBackward0>)
# brand generator weights tensor([ 0.5407, -1.5678, -0.1413,  1.1739,  1.1409,  0.5191,  0.4446, -1.2636,
#         -0.2387,  1.0692], grad_fn=<SelectBackward0>)
# gearbox generator weights tensor([-0.2466, -0.8208,  0.3392, -0.3811, -1.1093,  0.0802,  1.0885,  0.3169,
#          0.5265,  0.1427], grad_fn=<SelectBackward0>)
# brand discriminator weights tensor([ 0.5407, -1.5678, -0.1413,  1.1739,  1.1409,  0.5191,  0.4446, -1.2636,
#         -0.2387,  1.0692], grad_fn=<SelectBackward0>)
# gearbox discriminator weights tensor([-0.2466, -0.8208,  0.3392, -0.3811, -1.1093,  0.0802,  1.0885,  0.3169,
#          0.5265,  0.1427], grad_fn=<SelectBackward0>)

# %% [markdown]
# Now let's generate 20 made-up cars that achieves 12 km/L city and 18 km/L highway

# %%
generated_cars = 20

want_city = 12
want_highway = 18
want_city_normalized = (want_city - fuelcons_min) / (fuelcons_max - fuelcons_min)
want_hwy_normalized = (want_highway - fuelcons_min) / (fuelcons_max - fuelcons_min)
want_city_normalized = torch.tensor([want_city_normalized] * generated_cars).reshape(-1, 1).float()
want_hwy_normalized = torch.tensor([want_hwy_normalized] * generated_cars).reshape(-1, 1).float()
noise = torch.rand(size=(generated_cars, latent_vector_dim))
combined = torch.cat((want_city_normalized, want_hwy_normalized, noise), dim=1)

generated_data = generator(combined)
for car in generated_data:
    brand, gearbox, year, cc = car
    brand = all_brands_list[int(brand)]
    gearbox = all_gearboxes_list[int(gearbox)]
    cc = int((cc * (cc_max - cc_min)) + cc_min)
    year = int((year * (year_max - year_min)) + year_min)
    print(year, brand, cc, gearbox, "achieves", want_city, "city and", want_highway, "highway")
# Out:
# 2021 peugeot 916 CVT achieves 12 city and 18 highway
# 2021 peugeot 894 CVT achieves 12 city and 18 highway
# 2021 peugeot 896 CVT achieves 12 city and 18 highway
# 2021 peugeot 922 CVT achieves 12 city and 18 highway
# 2021 suzuki 910 CVT achieves 12 city and 18 highway
# 2021 suzuki 916 CVT achieves 12 city and 18 highway
# 2021 suzuki 909 CVT achieves 12 city and 18 highway
# 2021 peugeot 903 CVT achieves 12 city and 18 highway
# 2021 peugeot 901 CVT achieves 12 city and 18 highway
# 2021 peugeot 888 CVT achieves 12 city and 18 highway
# 2021 peugeot 916 CVT achieves 12 city and 18 highway
# 2021 suzuki 913 CVT achieves 12 city and 18 highway
# 2021 suzuki 909 CVT achieves 12 city and 18 highway
# 2021 peugeot 910 CVT achieves 12 city and 18 highway
# 2021 peugeot 888 CVT achieves 12 city and 18 highway
# 2021 peugeot 917 CVT achieves 12 city and 18 highway
# 2021 suzuki 907 CVT achieves 12 city and 18 highway
# 2021 peugeot 906 CVT achieves 12 city and 18 highway
# 2021 peugeot 895 CVT achieves 12 city and 18 highway
# 2021 peugeot 902 CVT achieves 12 city and 18 highway
